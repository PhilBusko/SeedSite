# %% [markdown]
# # Image Tutorial
#
# **Workflow:** Source notebook.
#
# **Objective:** To provide sample code for displaying and editing images.

# %%
import os, sys, json
import pandas as PD

# %%
import cv2 as CV
import IPython.display as DS

# %%
import django
BACKEND_PATH = os.path.dirname(os.path.dirname(os.getcwd()))
os.chdir(BACKEND_PATH)
os.environ["CLOUD_DB"] = "True" 
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "True"
django.setup()
# Out:
# Database Host: 34.74.56.48

# %%
import app_proj.common.utility as UT
import base_module.models as BM
DATA_PATH = os.path.join(UT.ROOT_PATH, 'base_module', 'data')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# easy display 

imagePath = os.path.join(DATA_PATH, 'first-shot.jpg')
DS.Image(filename=imagePath, width=300)

# %%
# display with opencv

imageCv = CV.imread(imagePath, CV.IMREAD_COLOR)
imageCv = CV.imencode('.png', imageCv)[1]
DS.Image(imageCv, width=350)
